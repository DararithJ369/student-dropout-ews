# %%
# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid', palette='deep')

plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['font.size'] = 11

# %% [markdown]
# Imports core libraries for data handling, clustering, and visualization, and sets plotting style defaults.

# %% [markdown]
# ## Load processed data

# %%
encoded_df = pd.read_csv('../data/student_dropout_processed.csv')
encoded_df.head()
# Out:
#    gender  living_with  distance  transport  attendance  absence  \
# 0       0            2         1          1           5        0
# 1       1            2         2          1           5        0
# 2       0            2         2          1           5        2
# 3       0            2         2          1           5        0
# 4       1            2         1          1           5        0
#
#    parental_education  family_income  work_support  monthly_average  ...  \
# 0                   3              1             0                2  ...
# 1                   3              1             0                1  ...
# 2                   3              1             0                1  ...
# 3                   1              1             0                1  ...
# 4                   1              1             0                2  ...
#
#    ses_score  support_index  commute_burden  financial_pressure  \
# 0          4              5               2                  -1
# 1          4              5               3                  -1
# 2          4              5               3                  -1
# 3          2              3               3                  -1
# 4          2              3               2                  -1
#
#    academic_risk  risk_score  weighted_risk_score  normalized_risk_score  \
# 0             -2           1                  0.2               0.500000
# 1             -1           2                  0.4               1.000000
# 2              1           5                  1.4               2.666667
# 3             -1           2                  0.4               1.000000
# 4             -2           1                  0.2               0.500000
#
#    high_risk_student  risk_group
# 0                  0         Low
# 1                  0         Low
# 2                  1        High
# 3                  0         Low
# 4                  0         Low
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### For clustering

# %% [markdown]
# ### Supervised Clustering (Target-Informed)
#
# Below we add a target-informed feature (target encoding) for supervised clustering. This makes clusters reflect the dropout outcome, so interpret it as **supervised segmentation**, not pure unsupervised discovery.

# %%
cluster_features = [
    'attendance_quality',
    'engagement_score',
    'ses_score',
    'support_index',
    'commute_burden',
    'weighted_risk_score'
]

# %% [markdown]
# Defines the feature set for clustering, excluding `weighted_risk_score` to avoid leakage from the dropout target.

# %% [markdown]
# ### For prediction

# %%
prediction_features = [
    'attendance_quality',
    'engagement_score',
    'ses_score',
    'support_index',
    'commute_burden'
]

# %% [markdown]
# Defines prediction features and excludes `weighted_risk_score` to reduce leakage risk.

# %% [markdown]
# to avoid leakage.

# %% [markdown]
# The weighted risk score was excluded from predictive modeling because it was partially derived from dropout-related indicators, which could introduce target leakage and artificially inflate model performance.

# %% [markdown]
# ## Clustering Student's Group
#
# We are going to GROUP students into low risk, medium risk, and high risk using KMeans.

# %%
X_cluster = encoded_df[cluster_features]

X_cluster.head()
# Out:
#    attendance_quality  engagement_score  ses_score  support_index  \
# 0                   5                 7          4              5
# 1                   5                 6          4              5
# 2                   3                 4          4              5
# 3                   5                 6          2              3
# 4                   5                 7          2              3
#
#    commute_burden  weighted_risk_score
# 0               2                  0.2
# 1               3                  0.4
# 2               3                  1.4
# 3               3                  0.4
# 4               2                  0.2

# %% [markdown]
# Builds the clustering matrix from selected features and previews the data.

# %%
plt.subplots(figsize=(15,10))
for feature in cluster_features:
    plt.subplot(2, 3, cluster_features.index(feature) + 1)
    sns.histplot(encoded_df[feature], kde=True, bins=10, color='skyblue')
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

mask = np.triu(
    np.ones_like(X_cluster.corr(), dtype=bool)
)

sns.heatmap(
    X_cluster.corr(),
    mask=mask,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Examines correlations among clustering features to spot redundancy or strong relationships.

# %%
sns.pairplot(X_cluster, diag_kind='kde', corner=True, palette='Set3')

plt.show()

# %% [markdown]
# Pairwise plots help reveal separability and non-linear relationships between features.

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X_cluster)

# %% [markdown]
# Standardizes features so KMeans distance calculations are on comparable scales.

# %% [markdown]
# ### Elbow method
#
# find best number of cluster

# %%
inertia = []
K = range(1, 10)

for k in K:
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    kmeans.fit(X_scaled)

    inertia.append(kmeans.inertia_)

# %% [markdown]
# Computes inertia across $k$ to support the elbow method selection.

# %% [markdown]
# ### Plot Elbow

# %%
plt.plot(K, inertia, 'bo-')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')   
plt.show()

# %% [markdown]
# Elbow plot visualizes diminishing returns as $k$ increases.

# %% [markdown]
# ### Silhouette Score

# %%
sil_scores = []

K = range(2, 10)

for k in K:
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X_scaled)

    score = silhouette_score(X_scaled, labels)

    sil_scores.append(score)

# %% [markdown]
# Computes silhouette scores for $k=2$ to $9$ to assess cluster separation quality.

# %%
plt.plot(K, sil_scores, marker='o')

plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis")

plt.show()

# %% [markdown]
# Silhouette plot highlights which $k$ yields better separation (higher is better).

# %% [markdown]
# ### Train final KMeans
#
# Usually choose k = 3

# %%
kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

encoded_df['cluster'] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# Fits final KMeans with $k=3$ and assigns each student to a cluster.

# %%
encoded_df['cluster'].value_counts()
# Out:
# cluster
# 1    201
# 0    144
# 2     55
# Name: count, dtype: int64

# %% [markdown]
# Shows the number of students in each cluster.

# %%
# Map clusters to true risk labels
risk_names = {
    0: 'High Risk',
    1: 'Medium Risk',
    2: 'Low Risk'
}

encoded_df['Risk Tier'] = encoded_df['cluster'].map(risk_names)

risk_palette = {
    'High Risk': sns.color_palette("Set1")[0],  # Red
    'Medium Risk': sns.color_palette("Set1")[1], # Blue
    'Low Risk': sns.color_palette("Set1")[2]     # Green
}

plt.figure(figsize=(8, 5))
sns.countplot(
    x='Risk Tier',
    order=['High Risk', 'Medium Risk', 'Low Risk'],
    data=encoded_df,
    palette=risk_palette
)
plt.title("Cluster Distribution")
plt.xlabel("Risk Tier")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Visualizes the cluster size distribution and maps clusters to risk labels.

# %% [markdown]
# ### PCA Cluster Visualization
#
# Reduce to 2 dimensions.

# %%
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
pca_df = pd.DataFrame()

pca_df['PCA1'] = X_pca[:,0]
pca_df['PCA2'] = X_pca[:,1]

pca_df['cluster'] = encoded_df['cluster']

# %%
pca_df['Risk Tier'] = pca_df['cluster'].map({
    0: 'High Risk',
    1: 'Medium Risk',
    2: 'Low Risk'
})

risk_palette = {
    'High Risk': sns.color_palette("Set1")[0],  # Red
    'Medium Risk': sns.color_palette("Set1")[1], # Blue
    'Low Risk': sns.color_palette("Set1")[2]     # Green
}

plt.figure(figsize=(10, 8))
sns.scatterplot(
    x='PCA1',
    y='PCA2',
    hue='Risk Tier',
    hue_order=['High Risk', 'Medium Risk', 'Low Risk'],
    palette=risk_palette,
    data=pca_df,
    s=100
)

plt.title("PCA Cluster Visualization")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title='Risk Tier')
plt.show()

# %% [markdown]
# ### Cluster Mean Heatmap

# %%
cluster_means = encoded_df.groupby('cluster')[cluster_features].mean()
cluster_means.index = cluster_means.index.map({
    0: 'High Risk',
    1: 'Medium Risk',
    2: 'Low Risk'
})

# Reorder index so that it plots consistently
cluster_means = cluster_means.reindex(['High Risk', 'Medium Risk', 'Low Risk'])

cluster_means
# Out:
#              attendance_quality  engagement_score  ses_score  support_index  \
# cluster
# High Risk              4.270833          5.423611   4.541667       5.305556
# Medium Risk            4.348259          5.462687   2.582090       2.875622
# Low Risk               2.163636          2.763636   2.781818       3.472727
#
#              commute_burden  weighted_risk_score
# cluster
# High Risk          3.229167             0.653472
# Medium Risk        3.069652             0.623881
# Low Risk           3.836364             1.298182

# %% [markdown]
# Calculates mean feature values for each cluster to profile risk groups.

# %%
sns.heatmap(
    cluster_means,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title("Cluster Feature Means")
plt.show()

# %%
labels = cluster_features

num_vars = len(labels)

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

angles += angles[:1]

# %%
fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))

for i in cluster_means.index:
    values = cluster_means.loc[i].tolist()
    values += values[:1]
    
    ax.plot(angles, values, label=i)
    ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title("Cluster Profiles Radar Chart")
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(15,10))
for feature in cluster_features:
    plt.subplot(2, 3, cluster_features.index(feature) + 1)
    sns.boxplot(
        x='Risk Tier',
        y=feature,
        data=encoded_df,
        order=['High Risk', 'Medium Risk', 'Low Risk'],
        hue='Risk Tier',
        palette=risk_palette,
    )
    plt.title(f'{feature} by Cluster')

plt.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(15,10))
for feature in cluster_features:

    plt.subplot(2, 3, cluster_features.index(feature) + 1)

    sns.violinplot(
        x='cluster',
        y=feature,
        data=encoded_df,
        inner='box',
        hue='cluster',
        palette="Set3"
    )

    plt.title(f'{feature} Distribution by Cluster')
plt.tight_layout
plt.show()

# %%
corr_df = encoded_df[cluster_features + ['cluster']]

mask = np.triu(
    np.ones_like(corr_df.corr(), dtype=bool)
)

sns.heatmap(corr_df.corr(), annot=True, cmap='coolwarm', mask=mask)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Correlation heatmap including `cluster` shows which features align with cluster labels.

# %%
sns.pairplot(encoded_df[cluster_features + ['cluster']], hue='cluster', corner=True, palette='Set2')
plt.show()
